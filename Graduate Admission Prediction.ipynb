# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Admission_Predict (2).csv')
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  CGPA  \
# 0             1        337          118                  4  4.5  9.65
# 1             2        324          107                  4  4.0  8.87
# 2             3        316          104                  3  3.0  8.00
# 3             4        322          110                  3  3.5  8.67
# 4             5        314          103                  2  2.0  8.21
# 5             6        330          115                  5  4.5  9.34
# 6             7        321          109                  3  3.0  8.20
# 7             8        308          101                  2  3.0  7.90
# 8             9        302          102                  1  2.0  8.00
# 9            10        323          108                  3  3.5  8.60
# 10           11        325          106                  3  3.5  8.40
# 11           12        327          111                  4  4.0  9.00
# ...

# %%
dataset = dataset.drop(["Serial No.","University Rating","SOP","Research"],axis = 1)

# %%
dataset
# Out:
#      GRE Score  TOEFL Score  CGPA  Chance of Admit
# 0          337          118  9.65              0.92
# 1          324          107  8.87              0.76
# 2          316          104  8.00              0.72
# 3          322          110  8.67              0.80
# 4          314          103  8.21              0.65
# 5          330          115  9.34              0.90
# 6          321          109  8.20              0.75
# 7          308          101  7.90              0.68
# 8          302          102  8.00              0.50
# 9          323          108  8.60              0.45
# 10         325          106  8.40              0.52
# 11         327          111  9.00              0.84
# 12         328          112  9.10              0.78
# 13         307          109  8.00              0.62
# 14         311          104  8.20              0.61
# 15         314          105  8.30              0.54
# 16         317          107  8.70              0.66
# ...

# %%
dataset.corr()
# Out:
#                   GRE Score  TOEFL Score      CGPA  Chance of Admit
# GRE Score          1.000000     0.835977  0.833060          0.802610
# TOEFL Score        0.835977     1.000000  0.828417          0.791594
# CGPA               0.833060     0.828417  1.000000          0.873289
# Chance of Admit    0.802610     0.791594  0.873289          1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset.isnull().any()
# Out:
# Serial No.          False
# GRE Score           False
# TOEFL Score         False
# CGPA                False
# Chance of Admit     False
# dtype: bool

# %%
x=dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([[337.  , 118.  ,   9.65],
#        [324.  , 107.  ,   8.87],
#        [316.  , 104.  ,   8.  ],
#        ...,
#        [330.  , 116.  ,   9.45],
#        [312.  , 103.  ,   8.78],
#        [333.  , 117.  ,   9.66]])

# %%
y=dataset.iloc[:,3:].values

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
# array([[323.  , 107.  ,   8.55],
#        [313.  , 101.  ,   8.04],
#        [311.  , 106.  ,   8.26],
#        [322.  , 107.  ,   8.46],
#        [320.  , 111.  ,   8.87],
#        [314.  , 106.  ,   8.25],
#        [312.  , 101.  ,   8.04],
#        [316.  , 109.  ,   8.76],
#        [323.  , 110.  ,   8.98],
#        [321.  , 112.  ,   9.06],
#        [335.  , 117.  ,   9.82],
#        [328.  , 115.  ,   9.16],
#        [313.  , 107.  ,   8.69],
#        [338.  , 120.  ,   9.66],
#        [325.  , 106.  ,   8.4 ],
#        [327.  , 112.  ,   8.72],
#        [312.  , 107.  ,   8.46],
#        [331.  , 112.  ,   9.8 ],
#        [305.  , 107.  ,   8.42],
#        [312.  , 105.  ,   8.02],
#        [298.  ,  99.  ,   7.6 ],
#        [317.  , 107.  ,   8.28],
#        [301.  , 104.  ,   7.89],
#        [317.  , 106.  ,   8.12],
#        [310.  , 104.  ,   8.37],
#        [296.  ,  97.  ,   7.8 ],
#        [329.  , 111.  ,   9.01],
#        [298.  ,  98.  ,   8.03],
# ...

# %%
x_test
# Out:
# array([[308.  , 106.  ,   8.21],
#        [321.  , 109.  ,   8.68],
#        [303.  , 100.  ,   8.06],
#        [295.  ,  99.  ,   7.65],
#        [316.  , 102.  ,   7.4 ],
#        [311.  ,  99.  ,   8.43],
#        [340.  , 120.  ,   9.5 ],
#        [331.  , 117.  ,   9.42],
#        [331.  , 115.  ,   9.44],
#        [305.  , 108.  ,   8.48],
#        [327.  , 104.  ,   8.84],
#        [322.  , 110.  ,   9.13],
#        [321.  , 109.  ,   8.54],
#        [315.  , 100.  ,   7.95],
#        [336.  , 119.  ,   9.8 ],
#        [329.  , 113.  ,   9.45],
#        [296.  ,  95.  ,   7.54],
#        [325.  , 112.  ,   8.92],
#        [332.  , 117.  ,   9.1 ],
#        [324.  , 107.  ,   8.66],
#        [339.  , 119.  ,   9.7 ],
#        [316.  , 110.  ,   8.78],
#        [325.  , 110.  ,   8.67],
#        [311.  , 102.  ,   8.64],
#        [320.  , 104.  ,   8.34],
#        [320.  , 110.  ,   8.56],
#        [317.  , 103.  ,   8.15],
#        [335.  , 115.  ,   9.68],
# ...

# %%
y_test
# Out:
# array([[0.75],
#        [0.69],
#        [0.64],
#        [0.57],
#        [0.64],
#        [0.71],
#        [0.96],
#        [0.94],
#        [0.92],
#        [0.61],
#        [0.71],
#        [0.86],
#        [0.79],
#        [0.58],
#        [0.97],
#        [0.89],
#        [0.44],
#        [0.55],
#        [0.87],
#        [0.81],
#        [0.89],
#        [0.69],
#        [0.73],
#        [0.68],
#        [0.74],
#        [0.72],
#        [0.65],
#        [0.93],
#        [0.64],
#        [0.67],
#        [0.76],
#        [0.75],
#        [0.75],
#        [0.76],
#        [0.73],
#        [0.89],
#        [0.57],
#        [0.64],
#        [0.8 ],
#        [0.8 ],
#        [0.94],
#        [0.84],
#        [0.61],
#        [0.58],
#        [0.68],
#        [0.77],
#        [0.71],
#        [0.74],
#        [0.39],
#        [0.78],
#        [0.86],
#        [0.63],
#        [0.91],
#        [0.9 ],
#        [0.47],
#        [0.64],
#        [0.75],
#        [0.64],
# ...

# %%
y_train
# Out:
# array([[0.73],
#        [0.62],
#        [0.79],
#        [0.71],
#        [0.85],
#        [0.62],
#        [0.68],
#        [0.77],
#        [0.87],
#        [0.86],
#        [0.96],
#        [0.78],
#        [0.72],
#        [0.95],
#        [0.52],
#        [0.74],
#        [0.75],
#        [0.94],
#        [0.71],
#        [0.5 ],
#        [0.46],
#        [0.66],
#        [0.68],
#        [0.73],
#        [0.7 ],
#        [0.49],
#        [0.81],
#        [0.34],
#        [0.71],
#        [0.68],
#        [0.54],
#        [0.66],
#        [0.78],
#        [0.94],
#        [0.47],
#        [0.65],
#        [0.61],
#        [0.71],
#        [0.42],
#        [0.59],
#        [0.95],
#        [0.94],
#        [0.67],
#        [0.87],
#        [0.96],
#        [0.78],
#        [0.85],
#        [0.64],
#        [0.86],
#        [0.77],
#        [0.57],
#        [0.77],
#        [0.65],
#        [0.85],
#        [0.83],
#        [0.78],
#        [0.79],
#        [0.64],
# ...

# %%
#plt.scatter(x_train[:,0],y_train,label="State",color="red")
plt.scatter(x_train[:,2],y_train,color="purple")
#plt.scatter(x_train[:,2],y_train,label="Admin",color="orange")
#plt.legend()
plt.show()
#plt.plot(x,y)

# %%
from sklearn.linear_model import LinearRegression
mr=LinearRegression()

# %%
mr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict=mr.predict(x_test)
y_predict
# Out:
# array([[0.64495136],
#        [0.7527212 ],
#        [0.5914144 ],
#        [0.51008718],
#        [0.52812617],
#        [0.65993615],
#        [0.95270164],
#        [0.91131998],
#        [0.90741479],
#        [0.68547238],
#        [0.77207988],
#        [0.82504341],
#        [0.73195386],
#        [0.60070612],
#        [0.9852308 ],
#        [0.89775807],
#        [0.48216016],
#        [0.80716658],
#        [0.86598585],
#        [0.74928471],
#        [0.97679922],
#        [0.7603206 ],
#        [0.76321009],
#        [0.70139508],
#        [0.68297228],
#        [0.73622252],
#        [0.64494983],
#        [0.95155225],
#        [0.64846206],
#        [0.72773247],
#        [0.78043572],
#        [0.68151889],
#        [0.75901922],
#        [0.77265585],
#        [0.63456718],
#        [0.85231923],
#        [0.51261218],
#        [0.63113222],
#        [0.79110661],
#        [0.84677866],
#        [0.88925074],
#        [0.83896828],
#        [0.8331405 ],
# ...

# %%
mr.predict([[337,118,9.65]])
# Out:
# array([[0.96167818]])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.731020128756636
